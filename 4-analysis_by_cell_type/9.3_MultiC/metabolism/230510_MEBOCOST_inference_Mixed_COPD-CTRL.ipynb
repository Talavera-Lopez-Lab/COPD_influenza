# %% [markdown]
# ### Notebook for the CCI-derived metabolism from scRNA-Seq using `mebocost` - Mixed cell states COPD-CTRL
#
# - **Developed by**: Carlos Talavera-López Ph.D
# - **Institute of Computational Biology - Computational Health Centre - Hemlholtz Munich**
# - v230510

# %% [markdown]
# ### Import required modules

# %%
import os,sys
import numpy as np
import scanpy as sc
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

from mebocost import mebocost
# Out:
# Warning (xlmhg): Failed to import "mhg_cython" C extension.
# Warning (xlmhg): Failed to import the "mhg_cython" C extension.Falling back to the pure Python implementation, which is very slow.

# %%
sc.settings.verbosity = 3
sc.logging.print_versions()
sc.settings.set_figure_params(dpi = 180, color_map = 'magma_r', dpi_save = 300, vector_friendly = True, format = 'svg')
# Out:
# WARNING: If you miss a compact list, please try `print_header`!
# The `sinfo` package has changed name and is now called `session_info` to become more discoverable and self-explanatory. The `sinfo` PyPI package will be kept around to avoid breaking old installs and you can downgrade to 0.3.2 if you want to use it without seeing this message. For the latest features and bug fixes, please install `session_info` instead. The usage and defaults also changed slightly, so please review the latest README at https://gitlab.com/joelostblom/session_info.
# -----
# anndata     0.8.0
# scanpy      1.8.2
# sinfo       0.3.4
# -----
# Cython              0.29.33
# PIL                 9.4.0
# adjustText          NA
# appnope             0.1.3
# asttokens           NA
# backcall            0.2.0
# beta_ufunc          NA
# binom_ufunc         NA
# cffi                1.15.1
# comm                0.1.3
# cpuinfo             NA
# cycler              0.10.0
# cython              0.29.33
# cython_runtime      NA
# dateutil            2.8.2
# debugpy             1.6.6
# decorator           5.1.1
# defusedxml          0.7.1
# executing           1.2.0
# fontTools           4.39.2
# h5py                3.8.0
# hypergeom_ufunc     NA
# ipykernel           6.22.0
# ipython_genutils    0.2.0
# ipywidgets          8.0.5
# jedi                0.18.2
# joblib              1.2.0
# kiwisolver          1.4.4
# llvmlite            0.39.1
# matplotlib          3.5.3
# mebocost            NA
# mpl_toolkits        NA
# natsort             8.3.1
# nbinom_ufunc        NA
# networkx            2.8.8
# numba               0.56.4
# numexpr             2.8.4
# numpy               1.23.5
# packaging           23.0
# pandas              1.4.4
# parso               0.8.3
# patsy               0.5.3
# pexpect             4.8.0
# pickleshare         0.7.5
# pkg_resources       NA
# platformdirs        3.1.1
# plotly              5.13.1
# prompt_toolkit      3.0.38
# psutil              5.9.4
# ptyprocess          0.7.0
# pure_eval           0.2.2
# pydev_ipython       NA
# pydevconsole        NA
# pydevd              2.9.5
# pydevd_file_utils   NA
# pydevd_plugins      NA
# pydevd_tracing      NA
# pygments            2.14.0
# pyparsing           3.0.9
# pytz                2022.7.1
# scipy               1.8.1
# seaborn             0.11.2
# setuptools          67.6.0
# six                 1.16.0
# sklearn             1.2.2
# stack_data          0.6.2
# statsmodels         0.13.5
# tables              3.8.0
# threadpoolctl       3.1.0
# tornado             6.2
# traitlets           5.9.0
# wcwidth             0.2.6
# xlmhg               2.5.4
# yaml                6.0
# zipp                NA
# zmq                 25.0.2
# -----
# IPython             8.11.0
# jupyter_client      8.1.0
# jupyter_core        5.3.0
# notebook            6.5.3
# -----
# Python 3.9.16 | packaged by conda-forge | (main, Feb  1 2023, 21:42:20) [Clang 14.0.6 ]
# macOS-13.3.1-x86_64-i386-64bit
# 6 logical CPU cores, i386
# -----
# Session information updated at 2023-05-10 11:47

# %% [markdown]
# ### Read in dataset

# %%
adata = sc.read_h5ad('../../../data/COPD-CTRL_Mixed_scVI-annotated_ctl230504.h5ad') 
adata
# Out:
# AnnData object with n_obs × n_vars = 1271 × 7000
#     obs: 'sex', 'age', 'ethnicity', 'PaCO2', 'donor', 'infection', 'disease', 'SMK', 'illumina_stimunr', 'bd_rhapsody', 'n_genes', 'doublet_scores', 'predicted_doublets', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt2', 'n_counts', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'condition', 'sample_group', '_scvi_batch', '_scvi_labels', 'IAV_score', 'group', 'C_scANVI', 'cell_type', 'leiden', 'leiden_states'
#     var: 'mt', 'ribo', 'n_cells_by_counts-V1', 'mean_counts-V1', 'pct_dropout_by_counts-V1', 'total_counts-V1', 'n_cells_by_counts-V2', 'mean_counts-V2', 'pct_dropout_by_counts-V2', 'total_counts-V2', 'n_cells_by_counts-V3', 'mean_counts-V3', 'pct_dropout_by_counts-V3', 'total_counts-V3', 'n_cells_by_counts-V4', 'mean_counts-V4', 'pct_dropout_by_counts-V4', 'total_counts-V4', 'n_cells_by_counts-V5', 'mean_counts-V5', 'pct_dropout_by_counts-V5', 'total_counts-V5', 'n_cells_by_counts-V6', 'mean_counts-V6', 'pct_dropout_by_counts-V6', 'total_counts-V6', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'C_scANVI_colors', 'PaCO2_colors', '_scvi_manager_uuid', '_scvi_uuid', 'age_colors', 'batch_colors', 'cell_type_colors', 'disease_colors', 'donor_colors', 'group_colors', 'hvg', 'infection_colors', 'leiden', 'leiden_colors', 'leiden_states_colors', 'neighbors', 'seed_labels_colors', 'umap'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap', '_scvi_extra_categorical_covs', '_scvi_extra_continuous_covs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# - Is data raw?

# %%
def X_is_raw(adata):
    return np.array_equal(adata.X.sum(axis=0).astype(int), adata.X.sum(axis = 0))

# %%
X_is_raw(adata)
# Out:
# True

# %% [markdown]
# ### Infer Highly Variable Genes to speed up and improve inference

# %%
adata_raw = adata.copy()
adata.layers['counts'] = adata.X.copy()

sc.pp.highly_variable_genes(
    adata,
    flavor = "seurat_v3",
    n_top_genes = 7000,
    layer = "counts",
    batch_key = "donor",
    subset = True
)

adata
# Out:
# If you pass `n_top_genes`, all cutoffs are ignored.
# extracting highly variable genes
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'highly_variable_rank', float vector (adata.var)
#     'means', float vector (adata.var)
#     'variances', float vector (adata.var)
#     'variances_norm', float vector (adata.var)
# AnnData object with n_obs × n_vars = 1271 × 7000
#     obs: 'sex', 'age', 'ethnicity', 'PaCO2', 'donor', 'infection', 'disease', 'SMK', 'illumina_stimunr', 'bd_rhapsody', 'n_genes', 'doublet_scores', 'predicted_doublets', 'batch', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'total_counts_ribo', 'pct_counts_ribo', 'percent_mt2', 'n_counts', 'percent_chrY', 'XIST-counts', 'S_score', 'G2M_score', 'condition', 'sample_group', '_scvi_batch', '_scvi_labels', 'IAV_score', 'group', 'C_scANVI', 'cell_type', 'leiden', 'leiden_states'
#     var: 'mt', 'ribo', 'n_cells_by_counts-V1', 'mean_counts-V1', 'pct_dropout_by_counts-V1', 'total_counts-V1', 'n_cells_by_counts-V2', 'mean_counts-V2', 'pct_dropout_by_counts-V2', 'total_counts-V2', 'n_cells_by_counts-V3', 'mean_counts-V3', 'pct_dropout_by_counts-V3', 'total_counts-V3', 'n_cells_by_counts-V4', 'mean_counts-V4', 'pct_dropout_by_counts-V4', 'total_counts-V4', 'n_cells_by_counts-V5', 'mean_counts-V5', 'pct_dropout_by_counts-V5', 'total_counts-V5', 'n_cells_by_counts-V6', 'mean_counts-V6', 'pct_dropout_by_counts-V6', 'total_counts-V6', 'highly_variable', 'highly_variable_rank', 'means', 'variances', 'variances_norm', 'highly_variable_nbatches'
#     uns: 'C_scANVI_colors', 'PaCO2_colors', '_scvi_manager_uuid', '_scvi_uuid', 'age_colors', 'batch_colors', 'cell_type_colors', 'disease_colors', 'donor_colors', 'group_colors', 'hvg', 'infection_colors', 'leiden', 'leiden_colors', 'leiden_states_colors', 'neighbors', 'seed_labels_colors', 'umap'
#     obsm: 'X_scANVI', 'X_scVI', 'X_umap', '_scvi_extra_categorical_covs', '_scvi_extra_continuous_covs'
#     layers: 'counts'
#     obsp: 'connectivities', 'distances'

# %% [markdown]
# ### Infer metabolic communications
#
# - The `mebocost.conf` file needs to be provided. It is in the original repo and after installation it will have the correct paths and should work out of the box. You could provide the full path to the file, or create a symlink.

# %%
mebo_obj = mebocost.create_obj(
                        adata = adata,
                        group_col = ['leiden_states'],
                        met_est = 'mebocost',
                        config_path = './mebocost.conf',
                        exp_mat = None,
                        cell_ann = None,
                        species = 'human',
                        met_pred = None,
                        met_enzyme = None,
                        met_sensor = None,
                        met_ann = None,
                        scFEA_ann = None,
                        compass_met_ann = None,
                        compass_rxn_ann = None,
                        gene_network = None,
                        gmt_path = None,
                        cutoff_exp = 'auto', ## automated cutoff to exclude lowly ranked 25% sensors across all cells
                        cutoff_met = 'auto', ## automated cutoff to exclude lowly ranked 25% metabolites across all cells
                        cutoff_prop = 0.25, ## at lease 25% of cells should be expressed the sensor or present the metabolite in the cell group (specified by group_col)
                        sensor_type = ['Receptor', 'Transporter', 'Nuclear Receptor'],
                        thread = 4
                        )
# Out:
# [May 10, 2023 11:48:10]: We get expression data with 7000 genes and 1271 cells.
# [May 10, 2023 11:48:10]: Data Preparation Done in 0.0383 seconds

# %% [markdown]
# ### Estimate metabolite presence
#
# - If you just want the table of metabolic activity, you can stop here and export it as a CSV file.

# %%
mebo_obj._load_config_()
mebo_obj.estimator()
# Out:
# [May 10, 2023 11:48:12]: Load config and read data based on given species [human].
# [May 10, 2023 11:48:14]: Estimtate metabolite level using mebocost

# %%
met_mat = pd.DataFrame(mebo_obj.met_mat.toarray(),
                      index = mebo_obj.met_mat_indexer,
                      columns = mebo_obj.met_mat_columns)
met_mat.head()
# Out:
#              711539-ST09_CSE_IAV-V1  235387-ST09_CSE_IAV-V1  \
# HMDB0003948                1.333333                     1.0
# HMDB0003712                1.333333                     1.0
# HMDB0003945                1.333333                     1.0
# HMDB0003949                1.333333                     1.0
# HMDB0001188                2.000000                     3.0
#
#              843167-ST09_CSE_IAV-V1  877284-ST09_CSE_IAV-V1  \
# HMDB0003948                     5.0                     1.0
# HMDB0003712                     5.0                     1.0
# HMDB0003945                     5.0                     1.0
# HMDB0003949                     5.0                     1.0
# HMDB0001188                     5.0                     1.0
#
#              648468-ST09_CSE_IAV-V1  684499-ST09_CSE_IAV-V1  \
# HMDB0003948                     1.0                1.333333
# HMDB0003712                     1.0                1.333333
# HMDB0003945                     1.0                1.333333
# HMDB0003949                     1.0                1.333333
# HMDB0001188                    -2.0                0.000000
#
#              809377-ST09_CSE_IAV-V1  93965-ST09_CSE_IAV-V1  \
# HMDB0003948                1.666667                    0.0
# HMDB0003712                1.666667                    0.0
# HMDB0003945                1.666667                    0.0
# HMDB0003949                1.666667                    0.0
# HMDB0001188                1.000000                    0.0
#
#              814434-ST09_CSE_IAV-V1  451431-ST09_CSE_IAV-V1  ...  \
# HMDB0003948                1.666667                1.666667  ...
# HMDB0003712                1.666667                1.666667  ...
# HMDB0003945                1.666667                1.666667  ...
# HMDB0003949                1.666667                1.666667  ...
# HMDB0001188                0.000000                3.000000  ...
#
#              8289470-CSE03_CTRL-V6  3421133-CSE03_CTRL-V6  \
# HMDB0003948                    1.0               0.666667
# HMDB0003712                    1.0               0.666667
# HMDB0003945                    1.0               0.666667
# HMDB0003949                    1.0               0.666667
# HMDB0001188                    4.0               0.000000
#
#              2683446-CSE03_CTRL-V6  9599699-CSE03_CTRL-V6  \
# HMDB0003948               0.333333                    0.0
# HMDB0003712               0.333333                    0.0
# HMDB0003945               0.333333                    0.0
# HMDB0003949               0.333333                    0.0
# HMDB0001188               0.000000                    0.0
#
#              4449851-CSE03_CTRL-V6  10779671-CSE03_CTRL-V6  \
# HMDB0003948                    0.0                     0.0
# HMDB0003712                    0.0                     0.0
# HMDB0003945                    0.0                     0.0
# HMDB0003949                    0.0                     0.0
# HMDB0001188                    2.0                     1.0
#
#              9908803-CSE03_CTRL-V6  4426756-CSE03_CTRL-V6  \
# HMDB0003948               0.333333                    1.0
# HMDB0003712               0.333333                    1.0
# HMDB0003945               0.333333                    1.0
# HMDB0003949               0.333333                    1.0
# HMDB0001188               2.000000                    0.0
#
#              3847373-CSE03_CTRL-V6  329543-CSE03_CTRL-V6
# HMDB0003948                    0.0              1.666667
# HMDB0003712                    0.0              1.666667
# HMDB0003945                    0.0              1.666667
# HMDB0003949                    0.0              1.666667
# HMDB0001188                    0.0              1.000000
#
# [5 rows x 1271 columns]

# %%
met_mat.shape
# Out:
# (395, 1271)

# %% [markdown]
# ### MEBOCOST cell-cell communication inference

# %%
commu_res = mebo_obj.infer_commu(
                                n_shuffle = 1000,
                                seed = 1712, 
                                Return = True, 
                                thread = 4,
                                save_permuation = False,
                                min_cell_number = 3
                            )
# Out:
# [May 10, 2023 11:48:23]: Load config and read data based on given species [human].
# [May 10, 2023 11:48:25]: Estimtate metabolite level using mebocost
# [May 10, 2023 11:48:35]: Infer communications
# [May 10, 2023 11:48:35]: Sensor type used ['Transporter', 'Receptor', 'Nuclear Receptor']
# [May 10, 2023 11:48:35]: Parameters: {shuffling: 1000 times, random seed: 1712, thread: 4}
# [May 10, 2023 11:48:35]: met_sensor: (95, 8)
# [May 10, 2023 11:48:35]: avg_exp: (796, 5) for (gene, cell) of needed
# [May 10, 2023 11:48:35]: avg_met: (395, 5) for (metabolite, cell) of needed
# [May 10, 2023 11:48:35]: shuffling 1000 times for generating backgroud
# [May 10, 2023 11:48:36]: take exp and met avg for shuffling
# [May 10, 2023 11:48:40]: thread: 4
# [May 10, 2023 11:48:41]: ABCA1 ~ HMDB0006247
# [May 10, 2023 11:48:41]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:41]: Calculating P-value
# [May 10, 2023 11:48:41]: SLC7A5 ~ HMDB0000641
# [May 10, 2023 11:48:41]: SLC7A1 ~ HMDB0000517
# [May 10, 2023 11:48:41]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:41]: Calculating P-value
# [May 10, 2023 11:48:41]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:41]: Calculating P-value
# [May 10, 2023 11:48:41]: ESR1 ~ HMDB0006247
# [May 10, 2023 11:48:41]: CD36 ~ HMDB0003276
# [May 10, 2023 11:48:41]: SLC5A6 ~ HMDB0000030
# [May 10, 2023 11:48:42]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:42]: Calculating P-value
# [May 10, 2023 11:48:42]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:42]: Calculating P-value
# [May 10, 2023 11:48:42]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:42]: Calculating P-value
# [May 10, 2023 11:48:42]: GRIA1 ~ HMDB0000148
# [May 10, 2023 11:48:42]: ADORA2B ~ HMDB0000050
# [May 10, 2023 11:48:42]: SLC11A2 ~ HMDB0015531
# [May 10, 2023 11:48:42]: CD36 ~ HMDB0000067
# [May 10, 2023 11:48:42]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:42]: Calculating P-value
# [May 10, 2023 11:48:42]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:42]: Calculating P-value
# [May 10, 2023 11:48:42]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:42]: Calculating P-value
# [May 10, 2023 11:48:42]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:42]: Calculating P-value
# [May 10, 2023 11:48:42]: GRIA3 ~ HMDB0000148
# [May 10, 2023 11:48:42]: LDLR ~ HMDB0000067
# [May 10, 2023 11:48:42]: SLC40A1 ~ HMDB0015531
# [May 10, 2023 11:48:42]: SLC38A2 ~ HMDB0000641
# [May 10, 2023 11:48:42]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:42]: Calculating P-value
# [May 10, 2023 11:48:42]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:42]: Calculating P-value
# [May 10, 2023 11:48:42]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:42]: Calculating P-value
# [May 10, 2023 11:48:42]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:42]: Calculating P-value
# [May 10, 2023 11:48:42]: GRM4 ~ HMDB0000148
# [May 10, 2023 11:48:42]: SCARB1 ~ HMDB0000067
# [May 10, 2023 11:48:42]: SLC16A1 ~ HMDB0001311
# [May 10, 2023 11:48:42]: SLC3A2 ~ HMDB0000641
# [May 10, 2023 11:48:42]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:42]: Calculating P-value
# [May 10, 2023 11:48:42]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:42]: Calculating P-value
# [May 10, 2023 11:48:42]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:42]: Calculating P-value
# [May 10, 2023 11:48:42]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:43]: Calculating P-value
# [May 10, 2023 11:48:43]: GRM8 ~ HMDB0000148
# [May 10, 2023 11:48:43]: ESR1 ~ HMDB0000145
# [May 10, 2023 11:48:43]: SLC20A2 ~ HMDB0001429
# [May 10, 2023 11:48:43]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:43]: Calculating P-value
# [May 10, 2023 11:48:43]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:43]: Calculating P-value
# [May 10, 2023 11:48:43]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:43]: Calculating P-value
# [May 10, 2023 11:48:43]: TFRC ~ HMDB0015531
# [May 10, 2023 11:48:43]: TRPV1 ~ HMDB0000148
# [May 10, 2023 11:48:43]: GABBR1 ~ HMDB0000112
# [May 10, 2023 11:48:43]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:43]: Calculating P-value
# [May 10, 2023 11:48:43]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:43]: Calculating P-value
# [May 10, 2023 11:48:43]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:43]: Calculating P-value
# [May 10, 2023 11:48:43]: HCAR1 ~ HMDB0001311
# [May 10, 2023 11:48:43]: S1PR3 ~ HMDB0000277
# [May 10, 2023 11:48:43]: TFR2 ~ HMDB0015531
# [May 10, 2023 11:48:43]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:43]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:43]: Calculating P-value
# [May 10, 2023 11:48:43]: Calculating P-value
# [May 10, 2023 11:48:43]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:43]: Calculating P-value
# [May 10, 2023 11:48:43]: PTGER2 ~ HMDB0001220
# [May 10, 2023 11:48:43]: SLC44A2 ~ HMDB0000097
# [May 10, 2023 11:48:43]: SLC13A5 ~ HMDB0000134
# [May 10, 2023 11:48:43]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:44]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:44]: Calculating P-value
# [May 10, 2023 11:48:44]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:44]: Calculating P-value
# [May 10, 2023 11:48:44]: Calculating P-value
# [May 10, 2023 11:48:44]: PTGER4 ~ HMDB0001220
# [May 10, 2023 11:48:44]: SLC44A4 ~ HMDB0000097
# [May 10, 2023 11:48:44]: SLC38A5 ~ HMDB0000641
# [May 10, 2023 11:48:44]: SLC3A2 ~ HMDB0000187
# [May 10, 2023 11:48:44]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:44]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:44]: Calculating P-value
# [May 10, 2023 11:48:44]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:44]: Calculating P-value
# [May 10, 2023 11:48:44]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:44]: Calculating P-value
# [May 10, 2023 11:48:44]: Calculating P-value
# [May 10, 2023 11:48:44]: STRA6 ~ HMDB0001358
# [May 10, 2023 11:48:44]: SLC16A1 ~ HMDB0000243
# [May 10, 2023 11:48:44]: SLC6A8 ~ HMDB0000112
# [May 10, 2023 11:48:44]: SLC7A11 ~ HMDB0000574
# [May 10, 2023 11:48:44]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:44]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:44]: Calculating P-value
# [May 10, 2023 11:48:44]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:44]: Calculating P-value
# [May 10, 2023 11:48:44]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:44]: Calculating P-value
# [May 10, 2023 11:48:44]: Calculating P-value
# [May 10, 2023 11:48:44]: SLC52A2 ~ HMDB0000244
# [May 10, 2023 11:48:44]: SLC13A5 ~ HMDB0000254
# [May 10, 2023 11:48:44]: SLC6A6 ~ HMDB0000112
# [May 10, 2023 11:48:44]: SLC7A5 ~ HMDB0000696
# [May 10, 2023 11:48:44]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:44]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:44]: Calculating P-value
# [May 10, 2023 11:48:44]: Calculating P-value
# [May 10, 2023 11:48:44]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:44]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:44]: Calculating P-value
# [May 10, 2023 11:48:44]: Calculating P-value
# [May 10, 2023 11:48:45]: SLC13A5 ~ HMDB0000094
# [May 10, 2023 11:48:45]: SLC28A3 ~ HMDB0000034
# [May 10, 2023 11:48:45]: SLC6A14 ~ HMDB0000641
# [May 10, 2023 11:48:45]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:45]: Calculating P-value
# [May 10, 2023 11:48:45]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:45]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:45]: Calculating P-value
# [May 10, 2023 11:48:45]: SLC43A2 ~ HMDB0000696
# [May 10, 2023 11:48:45]: Calculating P-value
# [May 10, 2023 11:48:45]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:45]: SLC22A5 ~ HMDB0000062
# [May 10, 2023 11:48:45]: SLC7A7 ~ HMDB0000641
# [May 10, 2023 11:48:45]: Calculating P-value
# [May 10, 2023 11:48:45]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:45]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:45]: Calculating P-value
# [May 10, 2023 11:48:45]: SLC7A2 ~ HMDB0000517
# [May 10, 2023 11:48:45]: Calculating P-value
# [May 10, 2023 11:48:45]: SLC2A9 ~ HMDB0000122
# [May 10, 2023 11:48:45]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:45]: SLC43A2 ~ HMDB0000574
# [May 10, 2023 11:48:45]: Calculating P-value
# [May 10, 2023 11:48:45]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:45]: Calculating P-value
# [May 10, 2023 11:48:45]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:45]: Calculating P-value
# [May 10, 2023 11:48:45]: SLC7A2 ~ HMDB0000182
# [May 10, 2023 11:48:45]: SLC2A1 ~ HMDB0000122
# [May 10, 2023 11:48:45]: SLC2A6 ~ HMDB0000122
# [May 10, 2023 11:48:45]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:45]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:45]: Calculating P-value
# [May 10, 2023 11:48:45]: Calculating P-value
# [May 10, 2023 11:48:45]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:45]: Calculating P-value
# [May 10, 2023 11:48:46]: SLC7A1 ~ HMDB0000182
# [May 10, 2023 11:48:46]: SLC2A3 ~ HMDB0000169
# [May 10, 2023 11:48:46]: SLC29A1 ~ HMDB0000296
# [May 10, 2023 11:48:46]: SLC2A3 ~ HMDB0000122
# [May 10, 2023 11:48:46]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:46]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:46]: Calculating P-value
# [May 10, 2023 11:48:46]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:46]: Calculating P-value
# [May 10, 2023 11:48:46]: Calculating P-value
# [May 10, 2023 11:48:46]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:46]: Calculating P-value
# [May 10, 2023 11:48:46]: SLC7A2 ~ HMDB0000214
# [May 10, 2023 11:48:46]: SLC2A1 ~ HMDB0000169
# [May 10, 2023 11:48:46]: SLC29A1 ~ HMDB0000195
# [May 10, 2023 11:48:46]: SLC2A8 ~ HMDB0000122
# [May 10, 2023 11:48:46]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:46]: Calculating P-value
# [May 10, 2023 11:48:46]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:46]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:46]: Calculating P-value
# [May 10, 2023 11:48:46]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:46]: Calculating P-value
# [May 10, 2023 11:48:46]: Calculating P-value
# [May 10, 2023 11:48:46]: SLC7A1 ~ HMDB0000214
# [May 10, 2023 11:48:46]: SLC29A1 ~ HMDB0000050
# [May 10, 2023 11:48:46]: SLC29A1 ~ HMDB0000089
# [May 10, 2023 11:48:46]: SLC2A12 ~ HMDB0000122
# [May 10, 2023 11:48:46]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:46]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:46]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:46]: Calculating P-value
# [May 10, 2023 11:48:46]: Calculating P-value
# [May 10, 2023 11:48:46]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:46]: Calculating P-value
# [May 10, 2023 11:48:46]: Calculating P-value
# [May 10, 2023 11:48:46]: SLC22A5 ~ HMDB0000097
# [May 10, 2023 11:48:46]: SLC29A1 ~ HMDB0000133
# [May 10, 2023 11:48:46]: SLC2A10 ~ HMDB0000122
# [May 10, 2023 11:48:47]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:47]: SLC5A5 ~ HMDB0000294
# [May 10, 2023 11:48:47]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:47]: Calculating P-value
# [May 10, 2023 11:48:47]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:47]: Calculating P-value
# [May 10, 2023 11:48:47]: Calculating P-value
# [May 10, 2023 11:48:47]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:47]: Calculating P-value
# [May 10, 2023 11:48:47]: SLC2A8 ~ HMDB0000660
# [May 10, 2023 11:48:47]: SLC29A1 ~ HMDB0000273
# [May 10, 2023 11:48:47]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:47]: SLC27A2 ~ HMDB0000806
# [May 10, 2023 11:48:47]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:47]: Calculating P-value
# [May 10, 2023 11:48:47]: Calculating P-value
# [May 10, 2023 11:48:47]: P2RY1 ~ HMDB0001341
# [May 10, 2023 11:48:47]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:47]: Calculating P-value
# [May 10, 2023 11:48:47]: SLC5A1 ~ HMDB0000294
# [May 10, 2023 11:48:47]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:47]: Calculating P-value
# [May 10, 2023 11:48:47]: SLC2A1 ~ HMDB0001514
# [May 10, 2023 11:48:47]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:47]: AQP3 ~ HMDB0000131
# [May 10, 2023 11:48:47]: Calculating P-value
# [May 10, 2023 11:48:47]: P2RY1 ~ HMDB0000538
# [May 10, 2023 11:48:47]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:47]: Calculating P-value
# [May 10, 2023 11:48:47]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:47]: Calculating P-value
# [May 10, 2023 11:48:47]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:47]: Calculating P-value
# [May 10, 2023 11:48:47]: CD38 ~ HMDB0001178
# [May 10, 2023 11:48:48]: OXGR1 ~ HMDB0000208
# [May 10, 2023 11:48:48]: RORB ~ HMDB0000067
# [May 10, 2023 11:48:48]: P2RY2 ~ HMDB0000538
# [May 10, 2023 11:48:48]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:48]: Calculating P-value
# [May 10, 2023 11:48:48]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:48]: Calculating P-value
# [May 10, 2023 11:48:48]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:48]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:48]: Calculating P-value
# [May 10, 2023 11:48:48]: Calculating P-value
# [May 10, 2023 11:48:48]: P2RX4 ~ HMDB0000538
# [May 10, 2023 11:48:48]: THRB ~ HMDB0000248
# [May 10, 2023 11:48:48]: AR ~ HMDB0000053
# [May 10, 2023 11:48:48]: P2RY2 ~ HMDB0000285
# [May 10, 2023 11:48:48]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:48]: Calculating P-value
# [May 10, 2023 11:48:48]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:48]: Calculating P-value
# [May 10, 2023 11:48:48]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:48]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:48]: Calculating P-value
# [May 10, 2023 11:48:48]: Calculating P-value
# [May 10, 2023 11:48:48]: P2RX7 ~ HMDB0000538
# [May 10, 2023 11:48:48]: RARA ~ HMDB0001358
# [May 10, 2023 11:48:48]: P2RY11 ~ HMDB0000538
# [May 10, 2023 11:48:48]: RARA ~ HMDB0001852
# [May 10, 2023 11:48:48]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:48]: Calculating P-value
# [May 10, 2023 11:48:48]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:48]: Calculating P-value
# [May 10, 2023 11:48:48]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:48]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:48]: Calculating P-value
# [May 10, 2023 11:48:48]: Calculating P-value
# [May 10, 2023 11:48:48]: RARB ~ HMDB0001358
# [May 10, 2023 11:48:48]: P2RY11 ~ HMDB0000285
# [May 10, 2023 11:48:48]: NR1H3 ~ HMDB0006247
# [May 10, 2023 11:48:48]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:48]: Calculating P-value
# [May 10, 2023 11:48:48]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:49]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:49]: Calculating P-value
# [May 10, 2023 11:48:49]: Calculating P-value
# [May 10, 2023 11:48:49]: RORA ~ HMDB0000067
# [May 10, 2023 11:48:49]: AR ~ HMDB0000077
# [May 10, 2023 11:48:49]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:49]: Calculating P-value
# [May 10, 2023 11:48:49]: Normalizing Cluster Mean and Calculating Communication Score
# [May 10, 2023 11:48:49]: Calculating P-value
# [May 10, 2023 11:48:49]: Calculating aboundance of metabolite and sensor expression in cell groups
# [May 10, 2023 11:48:49]: automated cutoff for sensor expression, cutoff=2.0
# [May 10, 2023 11:48:49]: automated cutoff for metabolite presence, cutoff=1.0
# [May 10, 2023 11:48:49]: cutoff_exp: 2.0
# [May 10, 2023 11:48:50]: cutoff_metabolite: 1.0
# [May 10, 2023 11:48:51]: Set p value and fdr to 1 if sensor or metaboltie expressed cell proportion less than 0.25
# [May 10, 2023 11:48:51]: Prediction Done in 28.6047 seconds
# [May 10, 2023 11:48:51]: Memory Usage in Peak 0.20 GB

# %%
print('sensor_exp cutoff: %s'%mebo_obj.cutoff_exp)
print('metabolite_presence cutoff: %s'%mebo_obj.cutoff_met)
# Out:
# sensor_exp cutoff: 2.0
# metabolite_presence cutoff: 1.0

# %% [markdown]
# ### Visualise MEBOCOST prediction

# %% [markdown]
# - Summary of the number of communication events

# %%
mebo_obj.eventnum_bar(
                    sender_focus = [],
                    metabolite_focus = [],
                    sensor_focus = [],
                    receiver_focus = [],
                    and_or = 'and',
                    pval_method = 'permutation_test_fdr',
                    pval_cutoff = 0.05,
                    comm_score_col = 'Commu_Score',
                    comm_score_cutoff = 0,
                    cutoff_prop = 0.25,
                    figsize = 'auto',
                    save = None,
                    show_plot = True,
                    show_num = True,
                    include = ['sender-receiver'],
                    group_by_cell = True,
                    colorcmap = 'tab20',
                    return_fig = False
                )

# %% [markdown]
# - Showing the communication between sender and receiver in a dot plot

# %%
mebo_obj.count_dot_plot(
                        pval_method = 'permutation_test_fdr',
                        pval_cutoff = 0.05,
                        cmap = 'plasma',
                        figsize = 'auto',
                        save = None,
                        dot_size_norm = (20, 200),
                        dot_color_vmin = None,
                        dot_color_vmax = 200,
                        show_plot = True,
                        comm_score_col = 'Commu_Score',
                        comm_score_cutoff = 0,
                        return_fig = False
                    )
# Out:
# [May 10, 2023 11:48:52]: plot dot plot to show communication in cell type level

# %% [markdown]
# - Showing the detailed communications (sender-receiver vs metabolite-sensor) in a dot map

# %%
mebo_obj.commu_dotmap(
                sender_focus = [],
                metabolite_focus = [],
                sensor_focus = [],
                receiver_focus = [],
                and_or = 'and',
                pval_method = 'permutation_test_fdr',
                pval_cutoff = 0.05,
                figsize = 'auto',
                cmap = 'plasma',
                node_size_norm = (10, 150),
                save = None,
                show_plot = True,
                comm_score_col = 'Commu_Score',
                comm_score_cutoff = 0,
                swap_axis = False,
                return_fig = False
                )
# Out:
# [May 10, 2023 11:48:52]: plot heatmap for significant result

# %% [markdown]
# - Visualization of the communication flow from sender metabolite to sensor in receiver

# %%
mebo_obj.FlowPlot(
                pval_method = 'permutation_test_fdr',
                pval_cutoff = 0.05,
                sender_focus = [],
                metabolite_focus = [],
                sensor_focus = [],
                receiver_focus = [],
                remove_unrelevant = False,
                and_or = 'and',
                node_label_size = 8,
                node_alpha = 0.6,
                figsize = 'auto',
                node_cmap = 'tab20',
                line_cmap = 'plasma',
                line_vmin = None,
                line_vmax = 15,
                node_size_norm = (20, 150),
                linewidth_norm = (0.5, 5),
                save = None,
                show_plot = True,
                comm_score_col = 'Commu_Score',
                comm_score_cutoff = 0,
                text_outline = False,
                return_fig = False
            )

# %%
mebo_obj.FlowPlot(
                pval_method = 'permutation_test_fdr',
                pval_cutoff = 0.05,
                sender_focus = [],
                metabolite_focus = [],
                sensor_focus = [],
                receiver_focus = [],
                remove_unrelevant = False,
                and_or = 'and',
                node_label_size = 8,
                node_alpha = 0.6,
                figsize = 'auto',
                node_cmap = 'tab20',
                line_cmap = 'RdPu',
                line_vmin = None,
                line_vmax = 15.5,
                node_size_norm = (20, 150),
                linewidth_norm = (0.5, 5),
                save = None,
                show_plot = True,
                comm_score_col = 'Commu_Score',
                comm_score_cutoff = 0,
                text_outline = False,
                return_fig = False
            )
# Out:
# [May 10, 2023 11:48:54]: plot flow plot to show the communications from Sender -> Metabolite -> Sensor -> Receiver

# %% [markdown]
# - Visualization of the metabolite level or sensor expression in cell groups

# %%
commu_df = mebo_obj.commu_res.copy()
good_met = commu_df[(commu_df['permutation_test_fdr']<=0.05)]['Metabolite_Name'].sort_values().unique()

mebo_obj.violin_plot(
                    sensor_or_met = good_met[:10], ## only top 5 as example
                    cell_focus = [],
                    cmap = 'RdPu',
                    vmin = None,
                    vmax = None,
                    figsize = 'auto',
                    cbar_title = '',
                    save = None,
                    show_plot = True
                    )
# Out:
# [May 10, 2023 11:48:55]: Warnings: no sensors to plot
# [May 10, 2023 11:48:55]: Find metabolites ['L-Cysteine', 'Pyruvic acid', 'L-Glutamine', 'gamma-Aminobutyric acid', 'Retinal', 'Iron', 'Choline'] to plot violin

# %%
good_sensor = commu_df[(commu_df['permutation_test_fdr']<=0.05)]['Sensor'].sort_values().unique()

mebo_obj.violin_plot(
                    sensor_or_met = good_sensor[:10],## only top 5 as example
                    cell_focus = [],
                    cmap = 'RdPu',
                    vmin = None,
                    vmax = None,
                    figsize = 'auto',
                    cbar_title = '',
                    save = None,
                    show_plot = True
                    )
# Out:
# [May 10, 2023 11:48:56]: Find genes Index(['RARB', 'SLC11A2', 'SLC16A1', 'SLC38A2', 'SLC38A5', 'SLC3A2', 'SLC43A2',
#        'SLC44A2', 'SLC44A4', 'SLC6A14'],
#       dtype='object') to plot violin
# [May 10, 2023 11:48:57]: Warnings: no metabolites to plot
